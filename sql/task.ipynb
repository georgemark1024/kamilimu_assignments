# %%
import sqlite3
import pandas as pd

# Load datasets
athletes = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-07-27/athlete_events.csv")
regions = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-07-27/noc_regions.csv")
sales = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
sales = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep='\t')

# Connect to SQLite in-memory DB
conn = sqlite3.connect(":memory:")

# Write DataFrames to SQL tables
athletes.to_sql("athletes_table", conn, index=False, if_exists="replace")
regions.to_sql("regions_table", conn, index=False, if_exists="replace")
sales.to_sql("sales_table", conn, index=False, if_exists="replace")
# Out:
# 4622

# %% [markdown]
# # Section 1
# Use the athletes, regions, and sales datasets.
#
# The athletes dataset:
#
# 1. Count the total number of medals won by each country and show the top 5.
#
# 2. Calculate the average age of athletes who won a Gold medal.
#
# 3. How many distinct events are there in each sport?
#
# 4. Show all athletes from the United States (NOC = 'USA').
#
# 5. Count how many medals were awarded each year.
#
# 6. Find all athlete records where height or weight is missing.

# %%
 # Total number of medals won by each country showing top 5
print("Athletes Table:")
pd.read_sql(
    """SELECT count(Medal) as total_medals, NOC
    FROM athletes_table
    WHERE Medal IS NOT NULL
    GROUP BY NOC
    ORDER BY total_medals DESC
    LIMIT 5
    """, conn)
# Out:
# Athletes Table:
#    total_medals  NOC
# 0          5637  USA
# 1          2503  URS
# 2          2165  GER
# 3          2068  GBR
# 4          1777  FRA

# %%
# Average age of atheletes who won GOLD medals
print("Average age of athletes who won GOLD medals:")
pd.read_sql(
    """SELECT AVG(Age) as average_age
    FROM athletes_table
    WHERE Medal = 'Gold'
    """, conn)
# Out:
# Average age of athletes who won GOLD medals:
#    average_age
# 0    25.901013

# %%
# How many distinct events are there in each sport
print("Number of distinct events in each sport:")
pd.read_sql(
    """SELECT Sport, COUNT(DISTINCT Event) as distinct_events
    FROM athletes_table
    GROUP BY Sport
    """, conn)
# Out:
# Number of distinct events in each sport:
#                Sport  distinct_events
# 0        Aeronautics                1
# 1      Alpine Skiing               10
# 2           Alpinism                1
# 3            Archery               29
# 4   Art Competitions               29
# ..               ...              ...
# 61        Tug-Of-War                1
# 62        Volleyball                2
# 63        Water Polo                2
# 64     Weightlifting               21
# 65         Wrestling               30
#
# [66 rows x 2 columns]

# %%
# All atheletes from NOC="USA"
print("All athletes from NOC='USA':")
pd.read_sql(
    """SELECT * 
    FROM athletes_table
    WHERE NOC = 'USA'
    """, conn
)
# Out:
# All athletes from NOC='USA':
#            ID                        Name Sex   Age  Height  Weight  \
# 0           6             Per Knut Aaland   M  31.0   188.0    75.0
# 1           6             Per Knut Aaland   M  31.0   188.0    75.0
# 2           6             Per Knut Aaland   M  31.0   188.0    75.0
# 3           6             Per Knut Aaland   M  31.0   188.0    75.0
# 4           6             Per Knut Aaland   M  33.0   188.0    75.0
# ...       ...                         ...  ..   ...     ...     ...
# 18848  135458                    Rami Zur   M  27.0   175.0    77.0
# 18849  135458                    Rami Zur   M  31.0   175.0    77.0
# 18850  135458                    Rami Zur   M  31.0   175.0    77.0
# 18851  135543  Victor Andrew "Vic" Zwolak   M  25.0   175.0    64.0
# 18852  135566  James Francis "Jim" Zylker   M  21.0   175.0    75.0
#
#                 Team  NOC        Games  Year  Season         City  \
# ...

# %%
# Count how many medals were awarded each year
pd.read_sql(
    """SELECT Year, COUNT(Medal) AS total_medals
    FROM athletes_table
    WHERE Medal IS NOT NULL
    GROUP BY Year
    """, conn
)
# Out:
#     Year  total_medals
# 0   1896           143
# 1   1900           604
# 2   1904           486
# 3   1906           458
# 4   1908           831
# 5   1912           941
# 6   1920          1308
# 7   1924           962
# 8   1928           823
# 9   1932           739
# 10  1936          1025
# 11  1948           987
# 12  1952          1033
# 13  1956          1043
# 14  1960          1058
# 15  1964          1215
# 16  1968          1256
# 17  1972          1414
# 18  1976          1531
# 19  1980          1602
# 20  1984          1698
# 21  1988          1845
# 22  1992          2030
# 23  1994           331
# 24  1996          1842
# 25  1998           440
# 26  2000          2004
# 27  2002           478
# 28  2004          2001
# 29  2006           526
# 30  2008          2048
# 31  2010           520
# 32  2012          1941
# 33  2014           597
# 34  2016          2023

# %%
# All missing height or weight records for athletes
pd.read_sql(
    """SELECT *
    FROM athletes_table
    WHERE Height IS NULL OR Weight IS NULL
""", conn
)
# Out:
#            ID                                Name Sex   Age  Height  Weight  \
# 0           3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 1           4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 2           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 3           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 4          10      Einar Ferdinand "Einari" Aalto   M  26.0     NaN     NaN
# ...       ...                                 ...  ..   ...     ...     ...
# 64258  135539               Marius Edmund Zwiller   M  18.0     NaN     NaN
# 64259  135542                      Werner Zwingli   M  29.0     NaN     NaN
# 64260  135542                      Werner Zwingli   M  29.0     NaN     NaN
# 64261  135552     Jan (Johann-) Zybert (Siebert-)   M  20.0     NaN     NaN
# 64262  135561                       Frantiek Zyka   M  26.0     NaN     NaN
#
# ...

# %% [markdown]
# The sales dataset: where necessary, use the key word CAST to remove the $ sign from the item_price
#
# 7. Replace the missing height with the average athlete height.
#
# 8. Return total sales value per item.
#
# 9. Show the top 5 records with the highest item_price.
#
# 10. How many unique customer orders are there? (Assume each order_id is a customer.)

# %%
# Replace missing height with the average athlete height

# Compute average height
athletes_copy = athletes.copy()
avg_height = athletes_copy['Height'].mean()
print(avg_height)

# Fill missing height values with the average height
athletes_copy['Height'] = athletes_copy['Height'].fillna(value=avg_height)

# Check if there are still null values in the Height column
null = athletes_copy['Height'].isna().to_list()
print(f"Null values = {null.count(True)}")

athletes_copy.head()
# Out:
# 175.33896987366376
# Null values = 0
#    ID                      Name Sex   Age     Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0  180.00000    80.0           China
# 1   2                  A Lamusi   M  23.0  170.00000    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0  175.33897     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0  175.33897     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0  185.00000    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# ...

# %%
# Return total sales value per item
sales.head()
pd.read_sql(
    """SELECT item_name, SUM(CAST(REPLACE(item_price, '$', '') AS FLOAT)) AS total
    FROM sales_table
    GROUP BY item_name
    ORDER BY total DESC""", conn
)
# Out:
#                                 item_name    total
# 0                            Chicken Bowl  7342.73
# 1                         Chicken Burrito  5575.82
# 2                           Steak Burrito  3851.43
# 3                              Steak Bowl  2260.19
# 4                     Chips and Guacamole  2201.04
# 5                      Chicken Salad Bowl  1228.75
# 6                      Chicken Soft Tacos  1108.09
# 7                          Veggie Burrito   934.77
# 8                        Barbacoa Burrito   894.75
# 9                             Veggie Bowl   867.99
# 10                          Carnitas Bowl   736.71
# 11                          Barbacoa Bowl   672.36
# 12                       Carnitas Burrito   597.83
# 13                       Steak Soft Tacos   536.05
# 14                                  Chips   494.34
# 15                   Chicken Crispy Tacos   472.13
# 16                      Canned Soft Drink   438.75
# ...

# %%
# Show the top 5 records with the highest item_price
pd.read_sql(
    """SELECT DISTINCT item_name, item_price
    FROM sales_table
    ORDER BY item_price DESC
    LIMIT 5""", conn
)
# Out:
#              item_name item_price
# 0     Steak Salad Bowl     $9.39
# 1  Barbacoa Salad Bowl     $9.39
# 2  Carnitas Salad Bowl     $9.39
# 3     Steak Soft Tacos     $9.25
# 4        Steak Burrito     $9.25

# %%
# How many unique customer orders are there (Assume each order_id is a customer)
sales.head()

pd.read_sql(
    """SELECT COUNT(DISTINCT order_id) AS customer_orders
    FROM sales_table
    """, conn
)
# Out:
#    customer_orders
# 0             1834

# %% [markdown]
# # Section 2
# Write one query for this section.
#
# Find countries with high-performing athletes in the Olympics. Use at least JOIN, NESTED QUERY, CASE, and optionally WITH.
#
# For each country:
#
# - Count the number of athletes who won at least one medal.
# - Determine the average age of those medalists.
# - Create a new column called performance:
#     - 'High' if average age is below 25
#     - 'Medium' if between 25 and 30
#     - 'Low' if above 30

# %%
pd.read_sql(
    """
    SELECT 
        r.region AS Country,
        medal_stats.medal_count,
        medal_stats.avg_age,
        CASE 
            WHEN medal_stats.avg_age < 25 THEN 'High'
            WHEN medal_stats.avg_age BETWEEN 25 AND 30 THEN 'Medium'
            ELSE 'Low'
        END AS performance
    FROM (
        SELECT 
            NOC,
            COUNT(DISTINCT ID) AS medal_count,
            ROUND(AVG(Age), 2) AS avg_age
        FROM athletes_table
        WHERE Medal IS NOT NULL
        GROUP BY NOC
    ) medal_stats
    JOIN regions_table r ON medal_stats.NOC = r.NOC
    ORDER BY medal_stats.avg_age
    """, conn
)
# Out:
#                          Country  medal_count  avg_age performance
# 0                           Iraq            1      NaN         Low
# 1                          Nepal            1      NaN         Low
# 2                       Botswana            1    18.00        High
# 3                        Curacao            1    19.00        High
# 4                          Ghana           23    19.17        High
# ..                           ...          ...      ...         ...
# 143                 Saudi Arabia            6    32.00         Low
# 144                      Vietnam            3    32.75         Low
# 145         United Arab Emirates            2    34.50         Low
# 146  Individual Olympic Athletes            5    34.60         Low
# 147                       Kuwait            1    39.00         Low
#
# [148 rows x 4 columns]
